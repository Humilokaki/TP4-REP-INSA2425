# %% [markdown]
# # Covid Home Advantage Analysis
#
# ## Table showing the difference between points gained at home and away (same with xPoints) from 2014 to 2020 for the 6 championships
#
# ### Step 1 : Load and extract the required data

# %%
import pandas as pd

# Load the data
data = pd.read_csv('../data/understat-football-matches-2014-2020.csv')

# Filter the data to only include matches from 2014 to 2018 seasons
data = data[(data['season'] >= 2014) & (data['season'] <= 2020)]

# Filter the data to only include the championships, season, h_a, pts and xpts columns
data = data[['championship', 'season', 'h_a', 'pts', 'xpts']]

data.head()
# Out:
#   championship  season h_a  pts    xpts
# 0      Ligue 1    2014   h    1  2.6417
# 1      Ligue 1    2014   a    3  2.1913
# 2      Ligue 1    2014   h    3  1.7855
# 3      Ligue 1    2014   a    1  0.1353
# 4      Ligue 1    2014   h    3  1.7712

# %% [markdown]
# ### Step 2 : Calculate the difference between points gained at home and away for each championship and season

# %%
# Total points gained at home and away for each championship and season
diff_pts = data.groupby(['championship', 'season', 'h_a'])['pts'].sum().unstack().fillna(0)
diff_pts['diff_pts'] = diff_pts['h'] - diff_pts['a']
diff_pts = diff_pts.reset_index()

# Same with xPoints
diff_xpts = data.groupby(['championship', 'season', 'h_a'])['xpts'].sum().unstack().fillna(0)
diff_xpts['diff_xpts'] = diff_xpts['h'] - diff_xpts['a']

# Combine the two dataframes by merging on championship, season with points and xPoints differences
data_diff = pd.merge(diff_pts, diff_xpts, on=['championship', 'season'])

# %% [markdown]
# ### Step 3 : Display the table showing the difference

# %%
import pandas as pd

# Assuming your data is in `df`
df = data_diff.rename(columns={'championship': 'LEAGUE', 'season': 'YEAR', 'diff_pts': 'DIFF_POINTS_HOMEAWAY', 'diff_xpts': 'DIFF_XPOINTS_HOMEAWAY'})

# Ensure that we're working with only the relevant columns
df = df[['LEAGUE', 'YEAR', 'DIFF_POINTS_HOMEAWAY', 'DIFF_XPOINTS_HOMEAWAY']]

# Round the values to integers
df['DIFF_POINTS_HOMEAWAY'] = df['DIFF_POINTS_HOMEAWAY'].round(0).astype(int)
df['DIFF_XPOINTS_HOMEAWAY'] = df['DIFF_XPOINTS_HOMEAWAY'].round(0).astype(int)

# Use Styler.bar to add horizontal bars to DIFF_POINTS_HOMEAWAY and DIFF_XPOINTS_HOMEAWAY
def add_bars_to_table(df):
    # Apply the bar style to the columns
    styled_df = df.style.bar(subset=['DIFF_POINTS_HOMEAWAY'], color=['red', 'lightgreen'], width=100, align='zero') \
                        .bar(subset=['DIFF_XPOINTS_HOMEAWAY'], color=['red', 'lightgreen'], width=100, align='zero') \
                        .set_table_styles([
                            {'selector': 'thead th', 'props': [('background-color', '#f2f2f2')]},  # Header styling
                            {'selector': 'tbody td', 'props': [('padding', '8px')]},  # Cell padding for better visibility
                            {'selector': 'table', 'props': [('border-collapse', 'collapse')]},  # Table border-collapse
                            {'selector': 'td', 'props': [('min-width', '80px')]}  # Ensure cell width is wide enough
                        ]) \
                        .hide(axis='index')  # Hide the index column for cleaner display
    
    return styled_df

# Display the styled table
styled_table = add_bars_to_table(df)
styled_table
# Out:
# <style type="text/css">
# #T_6eca1 thead th {
#   background-color: #f2f2f2;
# }
# #T_6eca1 tbody td {
#   padding: 8px;
# }
# #T_6eca1 table {
#   border-collapse: collapse;
# }
# #T_6eca1 td {
#   min-width: 80px;
# }
# #T_6eca1_row0_col2, #T_6eca1_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 88.4%, transparent 88.4%);
# }
# #T_6eca1_row0_col3, #T_6eca1_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 82.0%, transparent 82.0%);
# }
# #T_6eca1_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 70.3%, transparent 70.3%);
# }
# #T_6eca1_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 74.6%, transparent 74.6%);
# }
# #T_6eca1_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 89.5%, transparent 89.5%);
# }
# #T_6eca1_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 80.9%, transparent 80.9%);
# }
# #T_6eca1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.9%, transparent 83.9%);
# }
# #T_6eca1_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 75.0%, transparent 75.0%);
# }
# #T_6eca1_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 79.0%, transparent 79.0%);
# }
# #T_6eca1_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 54.7%, transparent 54.7%);
# }
# #T_6eca1_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.7%, transparent 62.7%);
# }
# #T_6eca1_row6_col2, #T_6eca1_row28_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 69.2%, transparent 69.2%);
# }
# #T_6eca1_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.5%, transparent 62.5%);
# }
# #T_6eca1_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.1%, transparent 83.1%);
# }
# #T_6eca1_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 93.4%, transparent 93.4%);
# }
# #T_6eca1_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 73.8%, transparent 73.8%);
# }
# #T_6eca1_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 77.8%, transparent 77.8%);
# }
# #T_6eca1_row9_col2, #T_6eca1_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 95.3%, transparent 95.3%);
# }
# #T_6eca1_row9_col3, #T_6eca1_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 82.6%, transparent 82.6%);
# }
# #T_6eca1_row10_col2, #T_6eca1_row36_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.8%, transparent 87.8%);
# }
# #T_6eca1_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.3%, transparent 87.3%);
# }
# #T_6eca1_row11_col2, #T_6eca1_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 80.8%, transparent 80.8%);
# }
# #T_6eca1_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 78.0%, transparent 78.0%);
# }
# #T_6eca1_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 72.2%, transparent 72.2%);
# }
# #T_6eca1_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.8%, red 44.8%, red 50.0%, transparent 50.0%);
# }
# #T_6eca1_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 60.2%, transparent 60.2%);
# }
# #T_6eca1_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.6%, transparent 92.6%);
# }
# #T_6eca1_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 86.7%, transparent 86.7%);
# }
# #T_6eca1_row16_col2, #T_6eca1_row23_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 91.3%, transparent 91.3%);
# }
# #T_6eca1_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 93.6%, transparent 93.6%);
# }
# #T_6eca1_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.2%, transparent 87.2%);
# }
# #T_6eca1_row17_col3, #T_6eca1_row23_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
# }
# #T_6eca1_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 94.3%, transparent 94.3%);
# }
# #T_6eca1_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.4%, transparent 92.4%);
# }
# #T_6eca1_row19_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 89.8%, transparent 89.8%);
# }
# #T_6eca1_row20_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 76.2%, transparent 76.2%);
# }
# #T_6eca1_row20_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 71.8%, transparent 71.8%);
# }
# #T_6eca1_row21_col2, #T_6eca1_row37_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 90.7%, transparent 90.7%);
# }
# #T_6eca1_row21_col3, #T_6eca1_row24_col2, #T_6eca1_row35_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 86.0%, transparent 86.0%);
# }
# #T_6eca1_row22_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 77.9%, transparent 77.9%);
# }
# #T_6eca1_row22_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 90.5%, transparent 90.5%);
# }
# #T_6eca1_row24_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.5%, transparent 87.5%);
# }
# #T_6eca1_row25_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.7%, transparent 83.7%);
# }
# #T_6eca1_row25_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 85.8%, transparent 85.8%);
# }
# #T_6eca1_row26_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 84.3%, transparent 84.3%);
# }
# #T_6eca1_row26_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 75.4%, transparent 75.4%);
# }
# #T_6eca1_row27_col2, #T_6eca1_row33_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.4%, red 49.4%, red 50.0%, transparent 50.0%);
# }
# #T_6eca1_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.9%, transparent 62.9%);
# }
# #T_6eca1_row28_col3, #T_6eca1_row32_col3, #T_6eca1_row40_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 73.5%, transparent 73.5%);
# }
# #T_6eca1_row29_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 63.4%, transpa

# %% [markdown]
# ### Conclusion
#
# - We can see I have the same results as the paper.
#
# ## Plotting the evolution of mean gained points (per match) for all seasons from 2014 and 2020
#
# ### Step 1 : Load and extract the required data

# %%
import pandas as pd

data = pd.read_csv('../data/understat-football-matches-2014-2020.csv')

# We only need the points, xPoints, result_away, xPointsAway, championships and season columns
data = data[['pts', 'xpts', 'h_a', 'championship', 'season']]

# Filter the data to only include matches from 2014 to 2020
data = data[(data['season'] >= 2014) & (data['season'] <= 2020)]

data.head()
# Out:
#    pts    xpts h_a championship  season
# 0    1  2.6417   h      Ligue 1    2014
# 1    3  2.1913   a      Ligue 1    2014
# 2    3  1.7855   h      Ligue 1    2014
# 3    1  0.1353   a      Ligue 1    2014
# 4    3  1.7712   h      Ligue 1    2014

# %% [markdown]
# ### Step 2 : Calculate the mean gained points per match for each season

# %%
# Calculate the mean gained points and expected points per match for each season by grouping by championship, season, and home/away
mean_stats = data.groupby(['championship', 'season', 'h_a']).agg(
    mean_pts=('pts', 'mean'),
    mean_xpts=('xpts', 'mean')
).unstack().fillna(0)

# Rename columns for clarity
mean_stats.columns = ['result_away', 'result', 'xPointsAway', 'xPoints']

# Reset index to make 'championship' and 'season' columns
mean_stats.reset_index(inplace=True)



mean_stats.head()
# Out:
#   championship  season  result_away    result  xPointsAway   xPoints
# 0   Bundesliga    2014     1.042484  1.689542     1.130599  1.623660
# 1   Bundesliga    2015     1.212418  1.555556     1.195821  1.576480
# 2   Bundesliga    2016     1.045752  1.712418     1.144089  1.620920
# 3   Bundesliga    2017     1.094771  1.633987     1.120375  1.642388
# 4   Bundesliga    2018     1.169935  1.591503     1.172744  1.621818

# %% [markdown]
# ### Step 3 : Plot the evolution of mean gained points per match for all seasons from 2014 to 2020

# %%
import matplotlib.pyplot as plt

# Plot the evolution of mean gained points per match for all seasons

for championship in mean_stats['championship'].unique():
    champ_data = mean_stats[mean_stats['championship'] == championship]
 
    plt.figure(figsize=(12, 6))
    plt.plot(champ_data['season'], champ_data['result'], label='result', marker='o', color='blue')
    plt.plot(champ_data['season'], champ_data['xPoints'], label='xPoints', marker='o', color='orange')
    plt.plot(champ_data['season'], champ_data['result_away'], label='result_away', marker="o", color='green')
    plt.plot(champ_data['season'], champ_data['xPointsAway'], label='xPointsAway', marker='o', color='red')
  
    plt.xlabel('Season')
    plt.ylabel('Mean Points per Match')
    plt.title('Evolution of Mean Gained Points per Match (2014-2020) - ' + championship)
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### Conclusion
#
# - We can see that I have the same results as the paper.
#
# ## Non-parametrical Wilcoxon Signed-Rank test to assess differences between home and away matches, considering either actual result, xPoints, or xG
#
# ### Step 1 : Load and extract the required data

# %%
from scipy.stats import wilcoxon
import numpy as np
import pandas as pd

data = pd.read_csv('../data/understat-football-matches-2014-2020.csv')

data = data[(data['season'] >= 2014) & (data['season'] <= 2020)]

data = data[['championship', 'season', 'pts', 'xpts', 'xG', 'h_a']]

data.head()
# Out:
#   championship  season  pts    xpts        xG h_a
# 0      Ligue 1    2014    1  2.6417  1.544680   h
# 1      Ligue 1    2014    3  2.1913  0.945961   a
# 2      Ligue 1    2014    3  1.7855  0.782421   h
# 3      Ligue 1    2014    1  0.1353  0.209403   a
# 4      Ligue 1    2014    3  1.7712  1.462930   h

# %% [markdown]
# ### Step 2 : Perform the Wilcoxon Signed-Rank test for each championship and season

# %%
wilcoxon_results = []

for (championship, season), group in data.groupby(['championship', 'season']):
    home_data = group[group['h_a'] == 'h']
    away_data = group[group['h_a'] == 'a']
    
    if len(home_data) == len(away_data):

        wilco_points = wilcoxon(home_data['pts'], away_data['pts'])
        
        wilco_xpoints = wilcoxon(home_data['xpts'], away_data['xpts'])
        
        wilco_xg = wilcoxon(home_data['xG'], away_data['xG'])
        
        def compute_cohens_d(a, b):
            diff = a.mean() - b.mean()
            pooled_std = np.sqrt(((len(a) - 1) * a.std()**2 + (len(b) - 1) * b.std()**2) / (len(a) + len(b) - 2))
            return diff / pooled_std if pooled_std != 0 else np.nan
        
        cohens_d_points = compute_cohens_d(home_data['pts'], away_data['pts'])
        cohens_d_xpoints = compute_cohens_d(home_data['xpts'], away_data['xpts'])
        cohens_d_xg = compute_cohens_d(home_data['xG'], away_data['xG'])
        
        # Append results to the list
        wilcoxon_results.append({
            'league': championship,
            'season': season,
            'wilco-result': wilco_points.statistic,
            'wilco-result-pvalue': wilco_points.pvalue,
            'result-cohend': cohens_d_points,
            'wilco-xpoint': wilco_xpoints.statistic,
            'wilco-xpoints-pvalue': wilco_xpoints.pvalue,
            'xpoints-cohend': cohens_d_xpoints,
            'wilco-xg': wilco_xg.statistic,
            'wilco-xg-pvalue': wilco_xg.pvalue,
            'xg-cohend': cohens_d_xg
        })

wilcoxon_df = pd.DataFrame(wilcoxon_results)

# %% [markdown]
# ### Step 3 : Format the results Table

# %%
# Highlight p-values < 0.05 and Cohen's d thresholds
def highlight_pval(val):
    return "background-color: red" if val < 0.05 else ""

def highlight_cohens_d(val):
    if val < 0.2:
        return "background-color: yellow"
    elif 0.2 <= val < 0.5:
        return "background-color: orange"
        
        return "background-color: red"
    return ""

styled_wilcoxon_df = wilcoxon_df.style.applymap(highlight_pval, subset=['wilco-result-pvalue', 'wilco-xpoints-pvalue', 'wilco-xg-pvalue']) \
                                       .applymap(highlight_cohens_d, subset=['result-cohend', 'xpoints-cohend', 'xg-cohend'])

styled_wilcoxon_df
# Out:
# <style type="text/css">
th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f357b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f357b_row0_col0" class="data row0 col0" >Bundesliga</td>
#       <td id="T_f357b_row0_col1" class="data row0 col1" >2014</td>
#       <td id="T_f357b_row0_col2" class="data row0 col2" >5550.000000</td>
#       <td id="T_f357b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f357b_row0_col4" class="data row0 col4" >0.512082</td>
#       <td id="T_f357b_row0_col5" class="data row0 col5" >11660.000000</td>
#       <td id="T_f357b_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_f357b_row0_col7" class="data row0 col7" >0.656084</td>
#       <td id="T_f357b_row0_col8" class="data row0 col8" >13479.000000</td>
#       <td id="T_f357b_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_f357b_row0_col10" class="data row0 col10" >0.494055</td>
#     </tr>
#     <tr>
#       <th id="T_f357b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f357b_row1_col0" class="data row1 col0" >Bundesliga</td>
#       <td id="T_f357b_row1_col1" class="data row1 col1" >2015</td>
#       <td id="T_f357b_row1_col2" class="data row1 col2" >6916.500000</td>
#       <td id="T_f357b_row1_col3" class="data row1 col3" >0.000981</td>
#       <td id="T_f357b_row1_col4" class="data row1 col4" >0.259479</td>
#       <td id="T_f357b_row1_col5" class="data row1 col5" >14055.500000</td>
#       <td id="T_f357b_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_f357b_row1_col7" class="data row1 col7" >0.458798</td>
#       <td id="T_f357b_row1_col8" class="data row1 col8" >15093.000000</td>
#       <td id="T_f357b_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_f357b_row1_col10" class="data row1 col10" >0.400803</td>
#     </tr>
#     <tr>
#       <th id="T_f357b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f357b_row2_col0" class="data row2 col0" >Bundesliga</td>
#       <td id="T_f357b_row2_col1" class="data row2 col1" >2016</td>
#       <td id="T_f357b_row2_col2" class="data row2 col2" >5251.000000</td>
#       <td id="T_f357b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_f357b_row2_col4" class="data row2 col4" >0.519632</td>
#       <td id="T_f357b_row2_col5" class="data row2 col5" >12081.000000</td>
#       <td id="T_f357b_row2_col6" class="da

# %% [markdown]
# ### Conclusion
#
# - Here, there is some differcences with the paper. The cohend d values are the same as the paper but the p-values and the statistics are different. They still are pretty close to the paper's results.
#
# ## Non-parametrical Mann-Whitney U test to assess differences between seasons (in terms of actual results home and xPoints home)
#
# ### Step 1 : Load and extract the required data

# %%
import pandas as pd

df = pd.read_csv('../data/understat-football-matches-2014-2020.csv')

df = df[(df['season'] >= 2014) & (df['season'] <= 2020)]

df = df[['championship', 'season', 'xpts', 'h_a']]

# Filter the data to only include home
df = df[df['h_a'] == 'h']

# %% [markdown]
# ### Step 2 : Perform the Mann-Whitney U test for each championship

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

leagues = df['championship'].unique()

def compute_mannwhitney_by_league(league, df):

    league_data = df[df['championship'] == league]
    
    seasons = sorted(league_data['season'].unique())
    
    p_values = []

    # Perform Mann-Whitney U test for each pair of seasons
    for season1 in seasons:
        row = []
        for season2 in seasons:
            data1 = league_data[league_data['season'] == season1]['xpts']
            data2 = league_data[league_data['season'] == season2]['xpts']
            
            stat, p_value = stats.mannwhitneyu(data1, data2)
            
            row.append(p_value)
        p_values.append(row)

    p_value_df = pd.DataFrame(p_values, columns=[str(s) for s in seasons], index=[str(s) for s in seasons])

    # Remove the upper triangular part (above the diagonal) to show only the lower part
    lower_triangular_mask = np.tril(np.ones(p_value_df.shape), k=-1).astype(bool)
    p_value_df = p_value_df.where(lower_triangular_mask)

    def highlight(p_value):
        if p_value < 0.05:
            return 'color: red'
        return ''

    styled_df = p_value_df.style.applymap(highlight)

    return styled_df

for league in leagues:
    print(f"\n{league} xPoints Change Significance with Mann-Whitney U Test")
    styled_table = compute_mannwhitney_by_league(league, df)
    
    display(styled_table)
# Out:
# Ligue 1 xPoints Change Significance with Mann-Whitney U Test
# <style type="text/css">
# #T_e0c25_row6_col0, #T_e0c25_row6_col1, #T_e0c25_row6_col2, #T_e0c25_row6_col3, #T_e0c25_row6_col4, #T_e0c25_row6_col5 {
#   color: red;
# }
# </style>
# <table id="T_e0c25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0c25_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_e0c25_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_e0c25_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_e0c25_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_e0c25_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_e0c25_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_e0c25_level0_col6" class="col_heading level0 col6" >2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0c25_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_e0c25_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_e0c25_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_e0c25_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_e0c25_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_e0c25_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_e0c25_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_e0c25_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e0c25_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_e0c25_row1_col0" class="data row1 col0" >0.251745</td>
#       <td id="T_e0c25_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_e0c25_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_e0c25_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_e0c25_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_e0c25_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_e0c25_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e0c25_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_e0c25_row2_col0" class="data row2 col0" >0.207138</td>
#       <td id="T_e0c25_row2_col1" class="data row2 col1" >0.448466</td>
#       <td id="T_e0c25_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_e0c25_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_e0c25_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_e0c25_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_e0c25_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e0c25_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_e0c25_row3_col0" class="data row3 col0" >0.321279</td>
#       <td id="T_e0c25_row3_col1" class="data row3 col1" >0.486951</td>
#       <td id="T_e0c25_row3_col2" class="data row3 col2" >0.416316</td>
#       <td id="T_e0c25_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_e0c25_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_e0c25_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_e0c25_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e0c25_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_e0c25_row4_col0" class="data row4 col0" >0.460318</td>
#       <td id="T_e0c25_row4_col1" class="data row4 col1" >0.307324</td>
#       <td id="T_e0c25_row4_col2" class="data row4 col2" >0.263694</td>
#       <td id="T_e0c25_row4_col3" class="data row4 col3" >0.357313</td>
#       <td id="T_e0c25_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_e0c25_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_e0c25_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e0c25_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_e0c25_row5_col0" class="data row5 col0" >0.475235</td>
#       <td id="T_e0c25_row5_col1" class="data row5 col1" >0.281316</td>
#       <td id="T_e0c25_row5_col2" class="data row5 col2" >0.229452</td>
#       <td id="T_e0c25_row5_col3" class="data row5 col3" >0.329968</td>
#       <td id="T_e0c25_row5_col4" class="data row5 col4" >0.452614</td>
#       <td id="T_e0c25_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_e0c25_row5_col6" class="data row5 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e0c25_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_e0c25_row6_col0" class="data row6 col0" >0.012854</td>
#       <td id="T_e0c25_row6_col1" class="data row6 col1" >0.003026</td>
#       <td id="T_e0c25_row6_col2" class="data row6 col2" >0.001609</td>
#       <td id="T_e0c25_row6_col3" class="data row6 col3" >0.005677</td>
#       <td id="T_e0c25_row6_col4" class="data row6 col4" >0.010800</td>
#       <td id="T_e0c25_row6_col5" class="data row6 col5" >0.022462</td>
#       <td id="T_e0c25_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# English Premier League xPoints Change Significance with Mann-Whitney U Test
# <style type="text/css">
# #T_8a7af_row5_col0, #T_8a7af_row6_col0, #T_8a7af_row6_col1, #T_8a7af_row6_col2, #T_8a7af_row6_col3, #T_8a7af_row6_col4 {
#   color: red;
# }
# </style>
# <table id="T_8a7af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a7af_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T
row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_3e5c2_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_3e5c2_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_3e5c2_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_3e5c2_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3e5c2_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_3e5c2_row3_col0" class="data row3 col0" >0.304484</td>
#       <td id="T_3e5c2_row3_col1" class="data row3 col1" >0.124564</td>
#       <td id="T_3e5c2_row3_col2" class="data row3 col2" >0.262131</td>
#       <td id="T_3e5c2_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_3e5c2_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_3e5c2_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_3e5c2_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3e5c2_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_3e5c2_row4_col0" class="data row4 col0" >0.401489</td>
#       <td id="T_3e5c2_row4_col1" class="data row4 col1" >0.311108</td>
#       <td id="T_3e5c2_row4_col2" class="data row4 col2" >0.435032</td>
#       <td id="T_3e5c2_row4_col3" class="data row4 col3" >0.204784</td>
#       <td id="T_3e5c2_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_3e5c2_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_3e5c2_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3e5c2_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_3e5c2_row5_col0" class="data row5 col0" >0.280138</td>
#       <td id="T_3e5c2_row5_col1" class="data row5 col1" >0.499473</td>
#       <td id="T_3e5c2_row5_col2" class="data row5 col2" >0.294325</td>
#       <td id="T_3e5c2_row5_col3" class="data row5 col3" >0.116348</td>
#       <td id="T_3e5c2_row5_col4" class="data row5 col4" >0.339354</td>
#       <td id="T_3e5c2_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_3e5c2_row5_col6" class="data row5 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3e5c2_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_3e5c2_row6_col0" class="data row6 col0" >0.010252</td>
#       <td id="T_3e5c2_row6_col1" class="data row6 col1" >0.041088</td>
#       <td id="T_3e5c2_row6_col2" class="data row6 col2" >0.010429</td>
#       <td id="T_3e5c2_row6_col3" class="data row6 col3" >0.001273</td>
#       <td id="T_3e5c2_row6_col4" class="data row6 col4" >0.009937</td>
#       <td id="T_3e5c2_row6_col5" class="data row6 col5" >0.030452</td>
#       <td id="T_3e5c2_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Serie A xPoints Change Significance with Mann-Whitney U Test
# <style type="text/css">
# #T_749cb_row6_col1, #T_749cb_row6_col2 {
#   color: red;
# }
# </style>
# <table id="T_749cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_749cb_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_749cb_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_749cb_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_749cb_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_749cb_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_749cb_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_749cb_level0_col6" class="col_heading level0 col6" >2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_749cb_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_749cb_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_749cb_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_749cb_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_749cb_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_749cb_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_749cb_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_749cb_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_749cb_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_749cb_row1_col0" class="data row1 col0" >0.380808</td>
#       <td id="T_749cb_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_749cb_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_749cb_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_749cb_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_749cb_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_749cb_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_749cb_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_749cb_row2_col0" class="data row2 col0" >0.492354</td>
#       <td id="T_749cb_row2_col1" class="data row2 col1" >0.420963</td>
#       <td id="T_749cb_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_749cb_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_749cb_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_749cb_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_749cb_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_749cb_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_749cb_row3_col0" class="data row3 col0" >0.071788</td>
#       <td id="T_749cb_row3_col1" class="data row3 col1" >0.050205</td>
#       <td id="T_749cb_row3_col2" class="data row3 col2" >0.090418</td>
#       <td id="T_749cb_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_749cb_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_749cb_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_749cb_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_749cb_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_749cb_row4_col0" class="data row4 col0" >0.492618</td>
#       <td id="T_749cb_row4_col1" class="data row4 col1" >0.362505</td>
#       <td id="T_749cb_row4_col2" class="data row4 col2" >0.474705</td>
#       <td id="T_749cb_row4_col3" class="data row4 col3" >0.078774</td>
#       <td id="T_749cb_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_749cb_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_749cb_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_749cb_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T
row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Russian Premier League xPoints Change Significance with Mann-Whitney U Test
# <style type="text/css">
# </style>
# <table id="T_81a1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81a1d_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_81a1d_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_81a1d_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_81a1d_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_81a1d_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_81a1d_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_81a1d_level0_col6" class="col_heading level0 col6" >2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81a1d_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_81a1d_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_81a1d_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_81a1d_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_81a1d_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_81a1d_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_81a1d_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_81a1d_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_81a1d_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_81a1d_row1_col0" class="data row1 col0" >0.244464</td>
#       <td id="T_81a1d_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_81a1d_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_81a1d_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_81a1d_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_81a1d_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_81a1d_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_81a1d_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_81a1d_row2_col0" class="data row2 col0" >0.241169</td>
#       <td id="T_81a1d_row2_col1" class="data row2 col1" >0.492911</td>
#       <td id="T_81a1d_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_81a1d_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_81a1d_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_81a1d_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_81a1d_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_81a1d_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_81a1d_row3_col0" class="data row3 col0" >0.477957</td>
#       <td id="T_81a1d_row3_col1" class="data row3 col1" >0.238307</td>
#       <td id="T_81a1d_row3_col2" class="data row3 col2" >0.246742</td>
#       <td id="T_81a1d_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_81a1d_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_81a1d_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_81a1d_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_81a1d_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_81a1d_row4_col0" class="data row4 col0" >0.480579</td>
#       <td id="T_81a1d_row4_col1" class="data row4 col1" >0.245912</td>
#       <td id="T_81a1d_row4_col2" class="data row4 col2" >0.241991</td>
#       <td id="T_81a1d_row4_col3" class="data row4 col3" >0.489368</td>
#       <td id="T_81a1d_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_81a1d_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_81a1d_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_81a1d_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_81a1d_row5_col0" class="data row5 col0" >0.092455</td>
#       <td id="T_81a1d_row5_col1" class="data row5 col1" >0.269055</td>
#       <td id="T_81a1d_row5_col2" class="data row5 col2" >0.249973</td>
#       <td id="T_81a1d_row5_col3" class="data row5 col3" >0.082621</td>
#       <td id="T_81a1d_row5_col4" class="data row5 col4" >0.083882</td>
#       <td id="T_81a1d_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_81a1d_row5_col6" class="data row5 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_81a1d_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_81a1d_row6_col0" class="data row6 col0" >0.401769</td>
#       <td id="T_81a1d_row6_col1" class="data row6 col1" >0.328437</td>
#       <td id="T_81a1d_row6_col2" class="data row6 col2" >0.333687</td>
#       <td id="T_81a1d_row6_col3" class="data row6 col3" >0.444909</td>
#       <td id="T_81a1d_row6_col4" class="data row6 col4" >0.459114</td>
#       <td id="T_81a1d_row6_col5" class="data row6 col5" >0.162341</td>
#       <td id="T_81a1d_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Conclusion
