# %% [markdown]
# # Covid Home Advantage Analysis
#
# ## Table showing the difference between points gained at home and away (same with xPoints) from 2014 to 2020 for the 6 championships
#
# ### Step 1 : Load and extract the required data

# %%
import pandas as pd

# Load the data
data = pd.read_csv('../data/understat-football-matches-2014-2024.csv')

# Filter the data to only include matches from 2014 to 2018 seasons
data = data[(data['season'] >= 2014) & (data['season'] <= 2024)]

# Filter the data to only include the championships, season, h_a, pts and xpts columns
data = data[['championship', 'season', 'h_a', 'pts', 'xpts']]

data.head()
# Out:
#   championship  season h_a  pts    xpts
# 0      Ligue 1    2014   h    1  2.6417
# 1      Ligue 1    2014   a    3  2.1913
# 2      Ligue 1    2014   h    3  1.7855
# 3      Ligue 1    2014   a    1  0.1353
# 4      Ligue 1    2014   h    3  1.7712

# %% [markdown]
# ### Step 2 : Calculate the difference between points gained at home and away for each championship and season

# %%
# Total points gained at home and away for each championship and season
diff_pts = data.groupby(['championship', 'season', 'h_a'])['pts'].sum().unstack().fillna(0)
diff_pts['diff_pts'] = diff_pts['h'] - diff_pts['a']
diff_pts = diff_pts.reset_index()

# Same with xPoints
diff_xpts = data.groupby(['championship', 'season', 'h_a'])['xpts'].sum().unstack().fillna(0)
diff_xpts['diff_xpts'] = diff_xpts['h'] - diff_xpts['a']

# Combine the two dataframes by merging on championship, season with points and xPoints differences
data_diff = pd.merge(diff_pts, diff_xpts, on=['championship', 'season'])

# %% [markdown]
# ### Step 3 : Display the table showing the difference

# %%
import pandas as pd

# Assuming your data is in `df`
df = data_diff.rename(columns={'championship': 'LEAGUE', 'season': 'YEAR', 'diff_pts': 'DIFF_POINTS_HOMEAWAY', 'diff_xpts': 'DIFF_XPOINTS_HOMEAWAY'})

# Ensure that we're working with only the relevant columns
df = df[['LEAGUE', 'YEAR', 'DIFF_POINTS_HOMEAWAY', 'DIFF_XPOINTS_HOMEAWAY']]

# Round the values to integers
df['DIFF_POINTS_HOMEAWAY'] = df['DIFF_POINTS_HOMEAWAY'].round(0).astype(int)
df['DIFF_XPOINTS_HOMEAWAY'] = df['DIFF_XPOINTS_HOMEAWAY'].round(0).astype(int)

# Use Styler.bar to add horizontal bars to DIFF_POINTS_HOMEAWAY and DIFF_XPOINTS_HOMEAWAY
def add_bars_to_table(df):
    # Apply the bar style to the columns
    styled_df = df.style.bar(subset=['DIFF_POINTS_HOMEAWAY'], color=['red', 'lightgreen'], width=100, align='zero') \
                        .bar(subset=['DIFF_XPOINTS_HOMEAWAY'], color=['red', 'lightgreen'], width=100, align='zero') \
                        .set_table_styles([
                            {'selector': 'thead th', 'props': [('background-color', '#f2f2f2')]},  # Header styling
                            {'selector': 'tbody td', 'props': [('padding', '8px')]},  # Cell padding for better visibility
                            {'selector': 'table', 'props': [('border-collapse', 'collapse')]},  # Table border-collapse
                            {'selector': 'td', 'props': [('min-width', '80px')]}  # Ensure cell width is wide enough
                        ]) \
                        .hide(axis='index')  # Hide the index column for cleaner display
    
    return styled_df

# Display the styled table
styled_table = add_bars_to_table(df)
styled_table
# Out:
# <style type="text/css">
# #T_5b419 thead th {
#   background-color: #f2f2f2;
# }
# #T_5b419 tbody td {
#   padding: 8px;
# }
# #T_5b419 table {
#   border-collapse: collapse;
# }
# #T_5b419 td {
#   min-width: 80px;
# }
# #T_5b419_row0_col2, #T_5b419_row26_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 88.4%, transparent 88.4%);
# }
# #T_5b419_row0_col3, #T_5b419_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 82.0%, transparent 82.0%);
# }
# #T_5b419_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 70.3%, transparent 70.3%);
# }
# #T_5b419_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 74.6%, transparent 74.6%);
# }
# #T_5b419_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 89.5%, transparent 89.5%);
# }
# #T_5b419_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 80.9%, transparent 80.9%);
# }
# #T_5b419_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.9%, transparent 83.9%);
# }
# #T_5b419_row4_col2, #T_5b419_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 75.0%, transparent 75.0%);
# }
# #T_5b419_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 79.0%, transparent 79.0%);
# }
# #T_5b419_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 54.7%, transparent 54.7%);
# }
# #T_5b419_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.7%, transparent 62.7%);
# }
# #T_5b419_row6_col2, #T_5b419_row44_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 69.2%, transparent 69.2%);
# }
# #T_5b419_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.5%, transparent 62.5%);
# }
# #T_5b419_row7_col2, #T_5b419_row15_col2, #T_5b419_row22_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 80.8%, transparent 80.8%);
# }
# #T_5b419_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 75.8%, transparent 75.8%);
# }
# #T_5b419_row8_col2, #T_5b419_row38_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 84.3%, transparent 84.3%);
# }
# #T_5b419_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 82.2%, transparent 82.2%);
# }
# #T_5b419_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 81.6%, transparent 81.6%);
# }
# #T_5b419_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 60.5%, transparent 60.5%);
# }
# #T_5b419_row10_col3, #T_5b419_row49_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 64.2%, transparent 64.2%);
# }
# #T_5b419_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.1%, transparent 83.1%);
# }
# #T_5b419_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 93.4%, transparent 93.4%);
# }
# #T_5b419_row12_col2, #T_5b419_row52_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 73.8%, transparent 73.8%);
# }
# #T_5b419_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 77.8%, transparent 77.8%);
# }
# #T_5b419_row13_col2, #T_5b419_row23_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 95.3%, transparent 95.3%);
# }
# #T_5b419_row13_col3, #T_5b419_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 82.6%, transparent 82.6%);
# }
# #T_5b419_row14_col2, #T_5b419_row56_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.8%, transparent 87.8%);
# }
# #T_5b419_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.3%, transparent 87.3%);
# }
# #T_5b419_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 78.0%, transparent 78.0%);
# }
# #T_5b419_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 72.2%, transparent 72.2%);
# }
# #T_5b419_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.8%, red 44.8%, red 50.0%, transparent 50.0%);
# }
# #T_5b419_row17_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 60.2%, transparent 60.2%);
# }
# #T_5b419_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 69.8%, transparent 69.8%);
# }
# #T_5b419_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 78.2%, transparent 78.2%);
# }
# #T_5b419_row19_col2, #T_5b419_row24_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 93.6%, transparent 93.6%);
# }
# #T_5b419_row19_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.5%, transparent 83.5%);
# }
# #T_5b419_row20_col2, #T_5b419_row53_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 80.2%, transparent 80.2%);
# }
# #T_5b419_row20_col3, #T_5b419_row26_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 94.3%, transparent 94.3%);
# }
# #T_5b419_row21_col2, #T_5b419_row42_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.7%, transparent 58.7%);
# }
# #T_5b419_row21_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.3%, transparent 62.3%);
# }
# #T_5b419_row22_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.6%, transparent 92.6%);
# }
# #T_5b419_row23_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 86.7%, transparent 86.7%);
# }
# #T_5b419_row24_col2, #T_5b419_row35_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 91.3%, transparent 91.3%);
# }
# #T_5b419_row25_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.2%, transparent 87.2%);
# }
# #T_5b419_row25_col3, #T_5b419_row35_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
# }
# #T_5b419_row27_col2, #T_5b419_row30_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.4%, transparent 92.4%);
# }
# #T_5b419_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 89.8%, transparent 89.8%);
# }
# #T_5b419_row28_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 76.2%, transparent 76.2%);
# }
# #T_5b419_row28_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 71.8%, transparent 71.8%);
# }
# #T_5b419_row29_col2, #T_5b419_row31_co

# %% [markdown]
# ### Conclusion
#
# - We can see I have the same results as the paper.
#
# ## Plotting the evolution of mean gained points (per match) for all seasons from 2014 and 2020
#
# ### Step 1 : Load and extract the required data

# %%
import pandas as pd

data = pd.read_csv('../data/understat-football-matches-2014-2024.csv')

# We only need the points, xPoints, result_away, xPointsAway, championships and season columns
data = data[['pts', 'xpts', 'h_a', 'championship', 'season']]

# Filter the data to only include matches from 2014 to 2024
data = data[(data['season'] >= 2014) & (data['season'] <= 2024)]

data.head()
# Out:
#    pts    xpts h_a championship  season
# 0    1  2.6417   h      Ligue 1    2014
# 1    3  2.1913   a      Ligue 1    2014
# 2    3  1.7855   h      Ligue 1    2014
# 3    1  0.1353   a      Ligue 1    2014
# 4    3  1.7712   h      Ligue 1    2014

# %% [markdown]
# ### Step 2 : Calculate the mean gained points per match for each season

# %%
# Calculate the mean gained points and expected points per match for each season by grouping by championship, season, and home/away
mean_stats = data.groupby(['championship', 'season', 'h_a']).agg(
    mean_pts=('pts', 'mean'),
    mean_xpts=('xpts', 'mean')
).unstack().fillna(0)

# Rename columns for clarity
mean_stats.columns = ['result_away', 'result', 'xPointsAway', 'xPoints']

# Reset index to make 'championship' and 'season' columns
mean_stats.reset_index(inplace=True)



mean_stats.head()
# Out:
#   championship  season  result_away    result  xPointsAway   xPoints
# 0   Bundesliga    2014     1.042484  1.689542     1.130599  1.623660
# 1   Bundesliga    2015     1.212418  1.555556     1.195821  1.576480
# 2   Bundesliga    2016     1.045752  1.712418     1.144089  1.620920
# 3   Bundesliga    2017     1.094771  1.633987     1.120375  1.642388
# 4   Bundesliga    2018     1.169935  1.591503     1.172744  1.621818

# %% [markdown]
# ### Step 3 : Plot the evolution of mean gained points per match for all seasons from 2014 to 2020

# %%
import matplotlib.pyplot as plt

# Plot the evolution of mean gained points per match for all seasons

for championship in mean_stats['championship'].unique():
    champ_data = mean_stats[mean_stats['championship'] == championship]
 
    plt.figure(figsize=(12, 6))
    plt.plot(champ_data['season'], champ_data['result'], label='result', marker='o', color='blue')
    plt.plot(champ_data['season'], champ_data['xPoints'], label='xPoints', marker='o', color='orange')
    plt.plot(champ_data['season'], champ_data['result_away'], label='result_away', marker="o", color='green')
    plt.plot(champ_data['season'], champ_data['xPointsAway'], label='xPointsAway', marker='o', color='red')
  
    plt.xlabel('Season')
    plt.ylabel('Mean Points per Match')
    plt.title('Evolution of Mean Gained Points per Match (2014-2024) - ' + championship)
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### Conclusion
#
# - We can see that I have the same results as the paper.
#
# ## Non-parametrical Wilcoxon Signed-Rank test to assess differences between home and away matches, considering either actual result, xPoints, or xG
#
# ### Step 1 : Load and extract the required data

# %%
from scipy.stats import ttest_rel
import numpy as np
import pandas as pd

data = pd.read_csv('../data/understat-football-matches-2014-2024.csv')

data = data[(data['season'] >= 2014) & (data['season'] <= 2024)]

data = data[['championship', 'season', 'pts', 'xpts', 'xG', 'h_a']]

data.head()
# Out:
#   championship  season  pts    xpts        xG h_a
# 0      Ligue 1    2014    1  2.6417  1.544680   h
# 1      Ligue 1    2014    3  2.1913  0.945961   a
# 2      Ligue 1    2014    3  1.7855  0.782421   h
# 3      Ligue 1    2014    1  0.1353  0.209403   a
# 4      Ligue 1    2014    3  1.7712  1.462930   h

# %% [markdown]
# ### Step 2 : Perform the Wilcoxon Signed-Rank test for each championship and season

# %%
ttest_results = []

for (championship, season), group in data.groupby(['championship', 'season']):
    home_data = group[group['h_a'] == 'h']
    away_data = group[group['h_a'] == 'a']
    
    if len(home_data) == len(away_data):

        ttest_points = ttest_rel(home_data['pts'], away_data['pts'])
        
        ttest_xpoints = ttest_rel(home_data['xpts'], away_data['xpts'])
        
        ttest_xg = ttest_rel(home_data['xG'], away_data['xG'])
        
        def compute_cohens_d(a, b):
            diff = a.mean() - b.mean()
            pooled_std = np.sqrt(((len(a) - 1) * a.std()**2 + (len(b) - 1) * b.std()**2) / (len(a) + len(b) - 2))
            return diff / pooled_std if pooled_std != 0 else np.nan
        
        cohens_d_points = compute_cohens_d(home_data['pts'], away_data['pts'])
        cohens_d_xpoints = compute_cohens_d(home_data['xpts'], away_data['xpts'])
        cohens_d_xg = compute_cohens_d(home_data['xG'], away_data['xG'])
        
        # Append results to the list
        ttest_results.append({
            'league': championship,
            'season': season,
            'wilco-result': ttest_points.statistic,
            'wilco-result-pvalue': ttest_points.pvalue,
            'result-cohend': cohens_d_points,
            'wilco-xpoint': ttest_xpoints.statistic,
            'wilco-xpoints-pvalue': ttest_xpoints.pvalue,
            'xpoints-cohend': cohens_d_xpoints,
            'wilco-xg': ttest_xg.statistic,
            'wilco-xg-pvalue': ttest_xg.pvalue,
            'xg-cohend': cohens_d_xg
        })

ttest_df = pd.DataFrame(ttest_results)

# %% [markdown]
# ### Step 3 : Format the results Table

# %%
# Highlight p-values < 0.05 and Cohen's d thresholds
def highlight_pval(val):
    return "background-color: red" if val < 0.05 else ""

def highlight_cohens_d(val):
    if val < 0.2:
        return "background-color: yellow"
    elif 0.2 <= val < 0.5:
        return "background-color: orange"
        
        return "background-color: red"
    return ""

styled_ttest_df = ttest_df.style.applymap(highlight_pval, subset=['wilco-result-pvalue', 'wilco-xpoints-pvalue', 'wilco-xg-pvalue']) \
                                       .applymap(highlight_cohens_d, subset=['result-cohend', 'xpoints-cohend', 'xg-cohend'])

styled_ttest_df
# Out:
# C:\Users\Noé\AppData\Local\Temp\ipykernel_15116\862921673.py:14: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_ttest_df = ttest_df.style.applymap(highlight_pval, subset=['wilco-result-pvalue', 'wilco-xpoints-pvalue', 'wilco-xg-pvalue']) \
# C:\Users\Noé\AppData\Local\Temp\ipykernel_15116\862921673.py:15: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(highlight_cohens_d, subset=['result-cohend', 'xpoints-cohend', 'xg-cohend'])
# <style type="text/css">
# #T_0db25_row0_col3, #T_0db25_row0_col6, #T_0db25_row0_col9, #T_0db25_row1_col3, #T_0db25_row1_col6, #T_0db25_row1_col9, #T_0db25_row2_col3, #T_0db25_row2_col6, #T_0db25_row2_col9, #T_0db25_row3_col3, #T_0db25_row3_col6, #T_0db25_row3_col9, #T_0db25_row4_col3, #T_0db25_row4_col6, #T_0db25_row4_col9, #T_0db25_row5_col6, #T_0db25_row5_col9, #T_0db25_row6_col3, #T_0db25_row6_col6, #T_0db25_row6_col9, #T_0db25_row7_col3, #T_0db25_row7_col6, #T_0db25_row7_col9, #T_0db25_row8_col3, #T_0db25_row8_col6, #T_0db25_row8_col9, #T_0db25_row9_col3, #T_0db25_row9_col6, #T_0db25_row9_col9, #T_0db25_row10_col3, #T_0db25_row10_col6, #T_0db25_row10_col9, #T_0db25_row11_col3, #T_0db25_row11_col6, #T_0db25_row11_col9, #T_0db25_row12_col3, #T_0db25_row12_col6, #T_0db25_row12_col9, #T_0db25_row13_col3, #T_0db25_row13_col6, #T_0db25_row13_col9, #T_0db25_row14_col3, #T_0db25_row14_col6, #T_0db25_row14_col9, #T_0db25_row15_col3, #T_0db25_row15_col6, #T_0db25_row15_col9, #T_0db25_row16_col3, #T_0db25_row16_col6, #T_0db25_row16_col9, #T_0db25_row17_col6, #T_0db25_row17_col9, #T_0db25_row18_col3, #T_0db25_row18_col6, #T_0db25_row18_col9, #T_0db25_row19_col3, #T_0db25_row19_col6, #T_0db25_row19_col9, #T_0db25_row20_col3, #T_0db25_row20_col6, #T_0db25_row20_col9, #T_0db25_row21_col6, #T_0db25_row21_col9, #T_0db25_row22_col3, #T_0db25_row22_col6, #T_0db25_row22_col9, #T_0db25_row23_col3, #T_0db25_row23_col6, #T_0db25_row23_col9, #T_0db25_row24_col3, #T_0db25_row24_col6, #T_0db25_row24_col9, #T_0db25_row25_col3, #T_0db25_row25_col6, #T_0db25_row25_col9, #T_0db25_row26_col3, #T_0db25_row26_col6, #T_0db25_row26_col9, #T_0db25_row27_col3, #T_0db25_row27_col6, #T_0db25_row27_col9, #T_0db25_row28_col3, #T_0db25_row28_col6, #T_0db25_row28_col9, #T_0db25_row29_col3, #T_0db25_row29_col6, #T_0db25_row29_col9, #T_0db25_row30_col3, #T_0db25_row30_col6, #T_0db25_row30_col9, #T_0db25_row31_col3, #T_0db25_row31_col6, #T_0db25_row31_col9, #T_0db25_row32_col3, #T_0db25_row32_col6, #T_0db25_row32_
# #T_0db25_row5_col4, #T_0db25_row5_col10, #T_0db25_row17_col4, #T_0db25_row17_col7, #T_0db25_row17_col10, #T_0db25_row21_col4, #T_0db25_row39_col4, #T_0db25_row39_col7, #T_0db25_row39_col10, #T_0db25_row42_col4, #T_0db25_row49_col4, #T_0db25_row54_col4, #T_0db25_row58_col4, #T_0db25_row60_col4, #T_0db25_row61_col4, #T_0db25_row61_col10, #T_0db25_row62_col4, #T_0db25_row65_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0db25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0db25_level0_col0" class="col_heading level0 col0" >league</th>
#       <th id="T_0db25_level0_col1" class="col_heading level0 col1" >season</th>
#       <th id="T_0db25_level0_col2" class="col_heading level0 col2" >wilco-result</th>
#       <th id="T_0db25_level0_col3" class="col_heading level0 col3" >wilco-result-pvalue</th>
#       <th id="T_0db25_level0_col4" class="col_heading level0 col4" >result-cohend</th>
#       <th id="T_0db25_level0_col5" class="col_heading level0 col5" >wilco-xpoint</th>
#       <th id="T_0db25_level0_col6" class="col_heading level0 col6" >wilco-xpoints-pvalue</th>
#       <th id="T_0db25_level0_col7" cl

# %% [markdown]
# ### Conclusion
#
# - Here, there is some differcences with the paper. The cohend d values are the same as the paper but the p-values and the statistics are different. They still are pretty close to the paper's results.
#
# ## Non-parametrical Mann-Whitney U test to assess differences between seasons (in terms of actual results home and xPoints home)
#
# ### Step 1 : Load and extract the required data

# %%
import pandas as pd

df = pd.read_csv('../data/understat-football-matches-2014-2024.csv')

df = df[(df['season'] >= 2014) & (df['season'] <= 2024)]

df = df[['championship', 'season', 'xpts', 'h_a']]

# Filter the data to only include home
df = df[df['h_a'] == 'h']

# %% [markdown]
# ### Step 2 : Perform the Mann-Whitney U test for each championship

# %%
import numpy as np
import pandas as pd

# Fonction pour effectuer un test de permutation
def permutation_test(data1, data2, n_permutations=1000, statistic=np.mean):
    # Calculer la statistique observée
    observed_stat = np.abs(statistic(data1) - statistic(data2))
    
    # Combiner les deux groupes
    combined = np.concatenate([data1, data2])
    
    # Permutations
    perm_stats = []
    for _ in range(n_permutations):
        np.random.shuffle(combined)
        perm_stats.append(
            np.abs(statistic(combined[:len(data1)]) - statistic(combined[len(data1):]))
        )
    
    # Calculer la p-value
    p_value = np.mean(perm_stats >= observed_stat)
    return observed_stat, p_value

# Fonction pour appliquer le test de permutation à chaque paire de saisons
def compute_permutation_by_league(league, df, n_permutations=1000):
    league_data = df[df['championship'] == league]
    seasons = sorted(league_data['season'].unique())
    
    p_values = []
    # Effectuer le test pour chaque paire de saisons
    for season1 in seasons:
        row = []
        for season2 in seasons:
            if season1 >= season2:
                row.append(np.nan)  # On remplit les parties inutiles avec NaN
                continue
            
            data1 = league_data[league_data['season'] == season1]['xpts']
            data2 = league_data[league_data['season'] == season2]['xpts']
            
            _, p_value = permutation_test(data1, data2, n_permutations=n_permutations)
            row.append(p_value)
        p_values.append(row)
    
    # Créer un DataFrame pour les p-values
    p_value_df = pd.DataFrame(
        p_values,
        columns=[str(s) for s in seasons],
        index=[str(s) for s in seasons]
    )
    
    # Appliquer un style pour mettre en évidence les p-values significatives
    def highlight(p_value):
        if not np.isnan(p_value) and p_value < 0.05:
            return 'color: red'
        return ''
    
    styled_df = p_value_df.style.applymap(highlight)
    return styled_df

# Appliquer le test de permutation pour chaque championnat et afficher le tableau stylisé
leagues = df['championship'].unique()

for league in leagues:
    print(f"\n{league} xPoints Change Significance with Permutation Test")
    styled_table = compute_permutation_by_league(league, df, n_permutations=1000)
    display(styled_table)
# Out:
# Ligue 1 xPoints Change Significance with Permutation Test
# C:\Users\Noé\AppData\Local\Temp\ipykernel_15116\718591766.py:58: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = p_value_df.style.applymap(highlight)
# <style type="text/css">
# #T_cf44f_row0_col6, #T_cf44f_row1_col6, #T_cf44f_row2_col6, #T_cf44f_row2_col8, #T_cf44f_row3_col6, #T_cf44f_row4_col6, #T_cf44f_row6_col9, #T_cf44f_row8_col9 {
#   color: red;
# }
# </style>
# <table id="T_cf44f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf44f_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_cf44f_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_cf44f_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_cf44f_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_cf44f_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_cf44f_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_cf44f_level0_col6" class="col_heading level0 col6" >2020</th>
#       <th id="T_cf44f_level0_col7" class="col_heading level0 col7" >2021</th>
#       <th id="T_cf44f_level0_col8" class="col_heading level0 col8" >2022</th>
#       <th id="T_cf44f_level0_col9" class="col_heading level0 col9" >2023</th>
#       <th id="T_cf44f_level0_col10" class="col_heading level0 col10" >2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf44f_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_cf44f_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_cf44f_row0_col1" class="data row0 col1" >0.547000</td>
#       <td id="T_cf44f_row0_col2" class="data row0 col2" >0.446000</td>
#       <td id="T_cf44f_row0_col3" class="data row0 col3" >0.660000</td>
#       <td id="T_cf44f_row0_col4" class="data row0 col4" >0.890000</td>
#       <td id="T_cf44f_row0_col5" class="data row0 col5" >0.977000</td>
#       <td id="T_cf44f_row0_col6" class="data row0 col6" >0.032000</td>
#       <td id="T_cf44f_row0_col7" class="data row0 col7" >0.765000</td>
#       <td id="T_cf44f_row0_col8" class="data row0 col8" >0.177000</td>
#       <td id="T_cf44f_row0_col9" class="data row0 col9" >0.382000</td>
#       <td id="T_cf44f_row0_col10" class="data row0 col10" >0.772000</td>
#     </tr>
#     <tr>
#       <th id="T_cf44f_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_cf44f_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_cf44f_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_cf44f_row1_col2" class="data row1 col2" >0.888000</td>
#       <td id="T_cf44f_row1_col3" class="data row1 col3" >0.852000</td>
#       <td id="T_cf44f_row1_col4" class="data row1 col4" >0.664000</td>
#       <td id="T_cf44f_row1_col5" class="data row1 col5" >0.574000</td>
#       <td id="T_cf44f_row1_col6" class="data row1 col6" >0.004000</td>
#       <td id="T_cf44f_row1_col7" class="data row1 col7" >0.392000</td>
#       <td id="T_cf44f_row1_col8" class="data row1 col8" >0.072000</td>
#       <td id="T_cf44f_row1_col9" class="data row1 col9" >0.756000</td>
#       <td id="T_cf44f_row1_col10" class="data row1 col10" >0.912000</td>
#     </tr>
#     <tr>
#       <th id="T_cf44f_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_cf44f_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_cf44f_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_cf44f_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_cf44f_row2_col3" class="data row2 col3" >0.760000</td>
#       <td id="T_cf44f_row2_col4" class="data row2 col4" >0.545000</td>
#       <td id="T_cf44f_row2_col5" class="data row2 col5" >0.491000</td>
#       <td id="T_cf44f_row2_col6" class="data row2 col6" >0.003000</td>
#       <td id="T_cf44f_row2_col7" class="data row2 col7" >0.322000</td>
#       <td id="T_cf44f_row2_col8" class="data row2 col8" >0.038000</td>
#       <td id="T_cf44f_row2_col9" class="data row2 col9" >0.864000</td>
#       <td id="T_cf44f_row2_col10" class="data row2 col10" >0.835000</td>
#     </tr>
#     <tr>
#       <th id="T_cf44f_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_cf44f_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_cf44f_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_cf44f_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_cf44f_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_cf44f_row3_col4" class="data row3 col4" >0.785000</td>
#       <td id="T_cf44f_row3_col5" class="data row3 col5" >0.706000</td>
#       <td id="T_cf44f_row3_col6" class="data row3 col6" >0.011000</td>
#       <td id="T_cf44f_row3_col7" class="data row3 col7" >0.509000</td>
#       <td id="T_cf44f_row3_col8" class="data row3 col8" >0.106000</td>
#       <td id="T_cf44f_row3_col9" class="data row3 col9" >0.650000</td>
#       <td id="T_cf44f_row3_col10" class="data row3 col10" >0.996000</td>
#     </tr>
#     <tr>
#       <th id="T_cf44f_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_cf44f_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_cf44f_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_cf44f_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_cf44f_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_cf44f_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_cf44f_row4_col5" class="data row4 col5" >0.909000</td>
#       <td id="T_cf44f_row4_col6" class="data row4 col6" >0.027000</td>
#       <td id="T_cf44f_row4_col7" class="data row4 col7" >0.682000</td>
#       <td id="T_cf44f_row4_col8" class="data row4 col8" >0.155000</td>
#       <td id="T_cf44f_row4_col9" class="data row4 col9" >0.456000</td>
#       <td id="T_cf44f_row4_col10" class="data row4 col10" >0.863000</td>
#     </tr>
#     <tr>
#       <th id="T_cf44f_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_cf44f_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_cf44f_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_cf44f_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_cf44f_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_cf44f_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_cf44f_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_cf44f_row5_col6" class="data row5 col6" >0.056000</td>
#       <td id="T_cf44f_row5_col7" class="data row5 col7" >0.798000</td>
#       <td id="T_cf44f_row5_col8" class="data row5 col8" >0.265000</td>
#       <td id="T_cf44f_row5_col9" class="data row5 col9" >0.432000</td>
#       <td id="T_cf44f_row5_col10" class="data row5 col10" >0.747000</td>
#     </tr>
#     <tr>
#       <th id="T_cf44f_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_cf44f_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_cf44f_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_cf44f_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_cf44f_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_cf44f_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_cf44f_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_cf44f_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_cf44f_row6_col7" class="data row6 col7" >0.066000</td>
#       <td id="T_cf44f_row6_col8" class="data row6 col8" >0.400000</td>
#       <td id="T_cf44f_row6_col9" class="data row6 col9" >0.005000</td>
#       <td id="T_cf44f_row6_col10" class="data row6 col10" >0.075000</td>
#     </tr>
#     <tr>
#       <th id="T_cf44f_level0_row7" class="row_heading level0 row7" >2021</th>
#       <td id="T_cf44f_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_cf44f_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_cf44f_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_cf44f_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_cf44f_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_cf44f_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_cf44f_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_cf44f_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_cf44f_row7_col8" class="data row7 col8" >0.335000</td>
#       <td id="T_cf44f_row7_col9" class="data row7 col9" >0.263000</td>
#       <td id="T_cf44f_row7_col10" clas
# English Premier League xPoints Change Significance with Permutation Test
# <style type="text/css">
# #T_3b86e_row0_col5, #T_3b86e_row0_col6, #T_3b86e_row1_col9, #T_3b86e_row2_col6, #T_3b86e_row3_col6, #T_3b86e_row5_col9, #T_3b86e_row6_col8, #T_3b86e_row6_col9 {
#   color: red;
# }
# </style>
# <table id="T_3b86e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b86e_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_3b86e_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_3b86e_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_3b86e_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_3b86e_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_3b86e_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_3b86e_level0_col6" class="col_heading level0 col6" >2020</th>
#       <th id="T_3b86e_level0_col7" class="col_heading level0 col7" >2021</th>
#       <th id="T_3b86e_level0_col8" class="col_heading level0 col8" >2022</th>
#       <th id="T_3b86e_level0_col9" class="col_heading level0 col9" >2023</th>
#       <th id="T_3b86e_level0_col10" class="col_heading level0 col10" >2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b86e_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_3b86e_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_3b86e_row0_col1" class="data row0 col1" >0.096000</td>
#       <td id="T_3b86e_row0_col2" class="data row0 col2" >0.301000</td>
#       <td id="T_3b86e_row0_col3" class="data row0 col3" >0.621000</td>
#       <td id="T_3b86e_row0_col4" class="data row0 col4" >0.170000</td>
#       <td id="T_3b86e_row0_col5" class="data row0 col5" >0.034000</td>
#       <td id="T_3b86e_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_3b86e_row0_col7" class="data row0 col7" >0.220000</td>
#       <td id="T_3b86e_row0_col8" class="data row0 col8" >0.447000</td>
#       <td id="T_3b86e_row0_col9" class="data row0 col9" >0.604000</td>
#       <td id="T_3b86e_row0_col10" class="data row0 col10" >0.126000</td>
#     </tr>
#     <tr>
#       <th id="T_3b86e_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_3b86e_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_3b86e_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_3b86e_row1_col2" class="data row1 col2" >0.597000</td>
#       <td id="T_3b86e_row1_col3" class="data row1 col3" >0.333000</td>
#       <td id="T_3b86e_row1_col4" class="data row1 col4" >0.867000</td>
#       <td id="T_3b86e_row1_col5" class="data row1 col5" >0.682000</td>
#       <td id="T_3b86e_row1_col6" class="data row1 col6" >0.101000</td>
#       <td id="T_3b86e_row1_col7" class="data row1 col7" >0.808000</td>
#       <td id="T_3b86e_row1_col8" class="data row1 col8" >0.431000</td>
#       <td id="T_3b86e_row1_col9" class="data row1 col9" >0.047000</td>
#       <td id="T_3b86e_row1_col10" class="data row1 col10" >0.922000</td>
#     </tr>
#     <tr>
#       <th id="T_3b86e_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_3b86e_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_3b86e_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_3b86e_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_3b86e_row2_col3" class="data row2 col3" >0.621000</td>
#       <td id="T_3b86e_row2_col4" class="data row2 col4" >0.713000</td>
#       <td id="T_3b86e_row2_col5" class="data row2 col5" >0.346000</td>
#       <td id="T_3b86e_row2_col6" class="data row2 col6" >0.033000</td>
#       <td id="T_3b86e_row2_col7" class="data row2 col7" >0.813000</td>
#       <td id="T_3b86e_row2_col8" class="data row2 col8" >0.810000</td>
#       <td id="T_3b86e_row2_col9" class="data row2 col9" >0.149000</td>
#       <td id="T_3b86e_row2_col10" class="data row2 col10" >0.593000</td>
#     </tr>
#     <tr>
#       <th id="T_3b86e_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_3b86e_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_3b86e_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_3b86e_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_3b86e_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T
row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_2cd1f_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_2cd1f_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_2cd1f_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_2cd1f_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_2cd1f_row4_col5" class="data row4 col5" >0.589000</td>
#       <td id="T_2cd1f_row4_col6" class="data row4 col6" >0.012000</td>
#       <td id="T_2cd1f_row4_col7" class="data row4 col7" >0.269000</td>
#       <td id="T_2cd1f_row4_col8" class="data row4 col8" >0.461000</td>
#       <td id="T_2cd1f_row4_col9" class="data row4 col9" >0.651000</td>
#       <td id="T_2cd1f_row4_col10" class="data row4 col10" >0.818000</td>
#     </tr>
#     <tr>
#       <th id="T_2cd1f_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_2cd1f_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_2cd1f_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_2cd1f_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_2cd1f_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_2cd1f_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_2cd1f_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_2cd1f_row5_col6" class="data row5 col6" >0.058000</td>
#       <td id="T_2cd1f_row5_col7" class="data row5 col7" >0.578000</td>
#       <td id="T_2cd1f_row5_col8" class="data row5 col8" >0.239000</td>
#       <td id="T_2cd1f_row5_col9" class="data row5 col9" >0.376000</td>
#       <td id="T_2cd1f_row5_col10" class="data row5 col10" >0.864000</td>
#     </tr>
#     <tr>
#       <th id="T_2cd1f_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_2cd1f_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_2cd1f_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_2cd1f_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_2cd1f_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_2cd1f_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_2cd1f_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_2cd1f_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_2cd1f_row6_col7" class="data row6 col7" >0.169000</td>
#       <td id="T_2cd1f_row6_col8" class="data row6 col8" >0.003000</td>
#       <td id="T_2cd1f_row6_col9" class="data row6 col9" >0.005000</td>
#       <td id="T_2cd1f_row6_col10" class="data row6 col10" >0.106000</td>
#     </tr>
#     <tr>
#       <th id="T_2cd1f_level0_row7" class="row_heading level0 row7" >2021</th>
#       <td id="T_2cd1f_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_2cd1f_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_2cd1f_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_2cd1f_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_2cd1f_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_2cd1f_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_2cd1f_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_2cd1f_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_2cd1f_row7_col8" class="data row7 col8" >0.090000</td>
#       <td id="T_2cd1f_row7_col9" class="data row7 col9" >0.132000</td>
#       <td id="T_2cd1f_row7_col10" class="data row7 col10" >0.561000</td>
#     <
# Serie A xPoints Change Significance with Permutation Test
# <style type="text/css">
# #T_a76ec_row1_col6 {
#   color: red;
# }
# </style>
# <table id="T_a76ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a76ec_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_a76ec_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_a76ec_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_a76ec_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_a76ec_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_a76ec_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_a76ec_level0_col6" class="col_heading level0 col6" >2020</th>
#       <th id="T_a76ec_level0_col7" class="col_heading level0 col7" >2021</th>
#       <th id="T_a76ec_level0_col8" class="col_heading level0 col8" >2022</th>
#       <th id="T_a76ec_level0_col9" class="col_heading level0 col9" >2023</th>
#       <th id="T_a76ec_level0_col10" class="col_heading level0 col10" >2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a76ec_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_a76ec_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a76ec_row0_col1" class="data row0 col1" >0.857000</td>
#       <td id="T_a76ec_row0_col2" class="data row0 col2" >0.971000</td>
#       <td id="T_a76ec_row0_col3" class="data row0 col3" >0.120000</td>
#       <td id="T_a76ec_row0_col4" class="data row0 col4" >0.961000</td>
#       <td id="T_a76ec_row0_col5" class="data row0 col5" >0.262000</td>
#       <td id="T_a76ec_row0_col6" class="data row0 col6" >0.081000</td>
#       <td id="T_a76ec_row0_col7" class="data row0 col7" >0.129000</td>
#       <td id="T_a76ec_row0_col8" class="data row0 col8" >0.231000</td>
#       <td id="T_a76ec_row0_col9" class="data row0 col9" >0.457000</td>
#       <td id="T_a76ec_row0_col10" class="data row0 col10" >0.292000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_a76ec_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_a76ec_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_a76ec_row1_col2" class="data row1 col2" >0.798000</td>
#       <td id="T_a76ec_row1_col3" class="data row1 col3" >0.116000</td>
#       <td id="T_a76ec_row1_col4" class="data row1 col4" >0.786000</td>
#       <td id="T_a76ec_row1_col5" class="data row1 col5" >0.208000</td>
#       <td id="T_a76ec_row1_col6" class="data row1 col6" >0.045000</td>
#       <td id="T_a76ec_row1_col7" class="data row1 col7" >0.087000</td>
#       <td id="T_a76ec_row1_col8" class="data row1 col8" >0.157000</td>
#       <td id="T_a76ec_row1_col9" class="data row1 col9" >0.334000</td>
#       <td id="T_a76ec_row1_col10" class="data row1 col10" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_a76ec_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_a76ec_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_a76ec_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a76ec_row2_col3" class="data row2 col3" >0.138000</td>
#       <td id="T_a76ec_row2_col4" class="data row2 col4" >0.990000</td>
#       <td id="T_a76ec_row2_col5" class="data row2 col5" >0.314000</td>
#       <td id="T_a76ec_row2_col6" class="data row2 col6" >0.104000</td>
#       <td id="T_a76ec_row2_col7" class="data row2 col7" >0.160000</td>
#       <td id="T_a76ec_row2_col8" class="data row2 col8" >0.264000</td>
#       <td id="T_a76ec_row2_col9" class="data row2 col9" >0.452000</td>
#       <td id="T_a76ec_row2_col10" class="data row2 col10" >0.342000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_a76ec_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_a76ec_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_a76ec_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_a76ec_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_a76ec_row3_col4" class="data row3 col4" >0.130000</td>
#       <td id="T_a76ec_row3_col5" class="data row3 col5" >0.731000</td>
#       <td id="T_a76ec_row3_col6" class="data row3 col6" >0.794000</td>
#       <td id="T_a76ec_row3_col7" class="data row3 col7" >0.948000</td>
#       <td id="T_a76ec_row3_col8" class="data row3 col8" >0.767000</td>
#       <td id="T_a76ec_row3_col9" class="data row3 col9" >0.493000</td>
#       <td id="T_a76ec_row3_col10" class="data row3 col10" >0.869000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_a76ec_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_a76ec_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_a76ec_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_a76ec_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_a76ec_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_a76ec_row4_col5" class="data row4 col5" >0.302000</td>
#       <td id="T_a76ec_row4_col6" class="data row4 col6" >0.076000</td>
#       <td id="T_a76ec_row4_col7" class="data row4 col7" >0.128000</td>
#       <td id="T_a76ec_row4_col8" class="data row4 col8" >0.271000</td>
#       <td id="T_a76ec_row4_col9" class="data row4 col9" >0.460000</td>
#       <td id="T_a76ec_row4_col10" class="data row4 col10" >0.309000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_a76ec_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_a76ec_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_a76ec_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_a76ec_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_a76ec_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_a76ec_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_a76ec_row5_col6" class="data row5 col6" >0.496000</td>
#       <td id="T_a76ec_row5_col7" class="data row5 col7" >0.649000</td>
#       <td id="T_a76ec_row5_col8" class="data row5 col8" >0.923000</td>
#       <td id="T_a76ec_row5_col9" class="data row5 col9" >0.758000</td>
#       <td id="T_a76ec_row5_col10" class="data row5 col10" >0.884000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_a76ec_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_a76ec_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_a76ec_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_a76ec_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_a76ec_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_a76ec_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_a76ec_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_a76ec_row6_col7" class="data row6 col7" >0.846000</td>
#       <td id="T_a76ec_row6_col8" class="data row6 col8" >0.565000</td>
#       <td id="T_a76ec_row6_col9" class="data row6 col9" >0.331000</td>
#       <td id="T_a76ec_row6_col10" class="data row6 col10" >0.728000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row7" class="row_heading level0 row7" >2021</th>
#       <td id="T_a76ec_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_a76ec_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_a76ec_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_a76ec_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_a76ec_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_a76ec_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_a76ec_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_a76ec_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_a76ec_row7_col8" class="data row7 col8" >0.719000</td>
#       <td id="T_a76ec_row7_col9" class="data row7 col9" >0.444000</td>
#       <td id="T_a76ec_row7_col10" class="data row7 col10" >0.831000</td>
#     </tr>
#     <tr>
#       <th id="T_a76ec_level0_row8" class="row_heading level0 row8" >2022</th>
#       <t
# Bundesliga xPoints Change Significance with Permutation Test
# <style type="text/css">
# #T_2a31f_row0_col6, #T_2a31f_row2_col6, #T_2a31f_row3_col5, #T_2a31f_row3_col6, #T_2a31f_row4_col6, #T_2a31f_row5_col8, #T_2a31f_row5_col9, #T_2a31f_row6_col8, #T_2a31f_row6_col9 {
#   color: red;
# }
# </style>
# <table id="T_2a31f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a31f_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_2a31f_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_2a31f_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_2a31f_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_2a31f_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_2a31f_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_2a31f_level0_col6" class="col_heading level0 col6" >2020</th>
#       <th id="T_2a31f_level0_col7" class="col_heading level0 col7" >2021</th>
#       <th id="T_2a31f_level0_col8" class="col_heading level0 col8" >2022</th>
#       <th id="T_2a31f_level0_col9" class="col_heading level0 col9" >2023</th>
#       <th id="T_2a31f_level0_col10" class="col_heading level0 col10" >2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a31f_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_2a31f_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_2a31f_row0_col1" class="data row0 col1" >0.471000</td>
#       <td id="T_2a31f_row0_col2" class="data row0 col2" >0.974000</td>
#       <td id="T_2a31f_row0_col3" class="data row0 col3" >0.780000</td>
#       <td id="T_2a31f_row0_col4" class="data row0 col4" >0.978000</td>
#       <td id="T_2a31f_row0_col5" class="data row0 col5" >0.052000</td>
#       <td id="T_2a31f_row0_col6" class="data row0 col6" >0.020000</td>
#       <td id="T_2a31f_row0_col7" class="data row0 col7" >0.625000</td>
#       <td id="T_2a31f_row0_col8" class="data row0 col8" >0.810000</td>
#       <td id="T_2a31f_row0_col9" class="data row0 col9" >0.783000</td>
#       <td id="T_2a31f_row0_col10" class="data row0 col10" >0.766000</td>
#     </tr>
#     <tr>
#       <th id="T_2a31f_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_2a31f_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_2a31f_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_2a31f_row1_col2" class="data row1 col2" >0.490000</td>
#       <td id="T_2a31f_row1_col3" class="data row1 col3" >0.340000</td>
#       <td id="T_2a31f_row1_col4" class="data row1 col4" >0.515000</td>
#       <td id="T_2a31f_row1_col5" class="data row1 col5" >0.223000</td>
#       <td id="T_2a31f_row1_col6" class="data row1 col6" >0.142000</td>
#       <td id="T_2a31f_row1_col7" class="data row1 col7" >0.858000</td>
#       <td id="T_2a31f_row1_col8" class="data row1 col8" >0.388000</td>
#       <td id="T_2a31f_row1_col9" class="data row1 col9" >0.341000</td>
#       <td id="T_2a31f_row1_col10" class="data row1 col10" >0.427000</td>
#     </tr>
#     <tr>
#       <th id="T_2a31f_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_2a31f_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_2a31f_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_2a31f_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_2a31f_row2_col3" class="data row2 col3" >0.731000</td>
#       <td id="T_2a31f_row2_col4" class="data row2 col4" >0.988000</td>
#       <td id="T_2a31f_row2_col5" class="data row2 col5" >0.074000</td>
#       <td id="T_2a31f_row2_col6" class="data row2 col6" >0.031000</td>
#       <td id="T_2a31f_row2_col7" class="data row2 col7" >0.652000</td>
#       <td id="T_2a31f_row2_col8" class="data row2 col8" >0.819000</td>
#       <td id="T_2a31f_row2_col9" class="data row2 col9" >0.761000</td>
#       <td id="T_2a31f_row2_col10" class="data row2 col10" >0.739000</td>
#     </tr>
#     <tr>
#       <th id="T_2a31f_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_2a31f_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_2a31f_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_2a31f_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_2a31f_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_2a31f_row3_col4" class="data row3 col4" >0.771000</td>
#       <td id="T_2a31f_row3_col5" class="data row3 col5" >0.021000</td>
#       <td id="T_2a31f_row3_col6" class="data row3 col6" >0.013000</td>
#       <td id="T_2a31f_row3_col7" class="data row3 col7" >0.405000</td>
#       <td id="T_2a31f_row3_col8" class="data row3 col8" >0.937000</td>
#       <td id="T_2a31f_row3_col9" class="data row3 col9" >0.999000</td>
#       <td id="T_2a31f_row3_col10" class="data row3 col10" >0.945000</td>
#     </tr>
#     <tr>
#       <th id="T_2a31f_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_2a31f_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_2a31f_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_2a31f_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_2a31f_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_2a31f_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_2a31f_row4_col5" class="data row4 col5" >0.059000</td>
#       <td id="T_2a31f_row4_col6" class="data row4 col6" >0.035000</td>
#       <td id="T_2a31f_row4_col7" class="data row4 col7" >0.635000</td>
#       <td id="T_2a31f_row4_col8" class="data row4 col8" >0.812000</td>
#       <td id="T_2a31f_row4_col9" class="data row4 col9" >0.765000</td>
#       <td id="T_2a31f_row4_col10" class="data row4 col10" >0.753000</td>
#     </tr>
#     <tr>
#       <th id="T_2a31f_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_2a31f_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_2a31f_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_2a31f_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_2a31f_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_2a31f_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_2a31f_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_2a31f_row5_col6" class="data row5 col6" >0.854000</td>
#       <td id="T_2a31f_row5_col7" class="data row5 col7" >0.156000</td>
#       <td id="T_2a31f_row5_col8" class="data row5 col8" >0.031000</td>
#       <td id="T_2a31f_row5_col9" class="data row5 col9" >0.034000</td>
#       <td id="T_2a31f_row5_col10" class="data row5 col10" >0.097000</td>
#     </tr>
#     <tr>
#       <th id="T_2a31f_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_2a31f_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_2a31f_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_2a31f_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_2a31f_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_2a31f_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_2a31f_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_2a31f_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_2a31f_row6_col7" class="data row6 col7" >0.110000</td>
#       <td id="T_2a31f_row6_col8" class="data row6 col8" >0.018000</td>
#       <td id="T_2a31f_row6_col9" class="data row6 col9" >0.017000</td>
#       <td id="T_2a31f_row6_col10" class="data row6 col10" >0.063000</td>
#     </tr>
#     <tr>
#       <th id="T_2a31f_level0_row7" class="row_heading level0 row7" >2021</th>
#       <td id="T_2a31f_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_2a31f_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_2a31f_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_2a31f_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_2a31f_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_2a31f_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_2a31f_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_2a31f_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_2a31f_row7_col8" class="data row7 col8" >0.476000</td>
#       <td id="T_2a31f_row7_col9" class="data row7 col9" >0.434000</td>
#       <td id="T_2a
# Russian Premier League xPoints Change Significance with Permutation Test
# <style type="text/css">
# </style>
# <table id="T_012bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_012bc_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_012bc_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_012bc_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_012bc_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_012bc_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_012bc_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_012bc_level0_col6" class="col_heading level0 col6" >2020</th>
#       <th id="T_012bc_level0_col7" class="col_heading level0 col7" >2021</th>
#       <th id="T_012bc_level0_col8" class="col_heading level0 col8" >2022</th>
#       <th id="T_012bc_level0_col9" class="col_heading level0 col9" >2023</th>
#       <th id="T_012bc_level0_col10" class="col_heading level0 col10" >2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_012bc_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_012bc_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_012bc_row0_col1" class="data row0 col1" >0.485000</td>
#       <td id="T_012bc_row0_col2" class="data row0 col2" >0.469000</td>
#       <td id="T_012bc_row0_col3" class="data row0 col3" >0.974000</td>
#       <td id="T_012bc_row0_col4" class="data row0 col4" >0.958000</td>
#       <td id="T_012bc_row0_col5" class="data row0 col5" >0.183000</td>
#       <td id="T_012bc_row0_col6" class="data row0 col6" >0.778000</td>
#       <td id="T_012bc_row0_col7" class="data row0 col7" >0.306000</td>
#       <td id="T_012bc_row0_col8" class="data row0 col8" >0.753000</td>
#       <td id="T_012bc_row0_col9" class="data row0 col9" >0.688000</td>
#       <td id="T_012bc_row0_col10" class="data row0 col10" >0.425000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_012bc_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_012bc_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_012bc_row1_col2" class="data row1 col2" >0.979000</td>
#       <td id="T_012bc_row1_col3" class="data row1 col3" >0.475000</td>
#       <td id="T_012bc_row1_col4" class="data row1 col4" >0.513000</td>
#       <td id="T_012bc_row1_col5" class="data row1 col5" >0.581000</td>
#       <td id="T_012bc_row1_col6" class="data row1 col6" >0.694000</td>
#       <td id="T_012bc_row1_col7" class="data row1 col7" >0.742000</td>
#       <td id="T_012bc_row1_col8" class="data row1 col8" >0.732000</td>
#       <td id="T_012bc_row1_col9" class="data row1 col9" >0.700000</td>
#       <td id="T_012bc_row1_col10" class="data row1 col10" >0.856000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_012bc_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_012bc_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_012bc_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_012bc_row2_col3" class="data row2 col3" >0.484000</td>
#       <td id="T_012bc_row2_col4" class="data row2 col4" >0.508000</td>
#       <td id="T_012bc_row2_col5" class="data row2 col5" >0.522000</td>
#       <td id="T_012bc_row2_col6" class="data row2 col6" >0.694000</td>
#       <td id="T_012bc_row2_col7" class="data row2 col7" >0.729000</td>
#       <td id="T_012bc_row2_col8" class="data row2 col8" >0.714000</td>
#       <td id="T_012bc_row2_col9" class="data row2 col9" >0.713000</td>
#       <td id="T_012bc_row2_col10" class="data row2 col10" >0.827000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_012bc_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_012bc_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_012bc_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_012bc_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_012bc_row3_col4" class="data row3 col4" >0.989000</td>
#       <td id="T_012bc_row3_col5" class="data row3 col5" >0.192000</td>
#       <td id="T_012bc_row3_col6" class="data row3 col6" >0.792000</td>
#       <td id="T_012bc_row3_col7" class="data row3 col7" >0.294000</td>
#       <td id="T_012bc_row3_col8" class="data row3 col8" >0.769000</td>
#       <td id="T_012bc_row3_col9" class="data row3 col9" >0.693000</td>
#       <td id="T_012bc_row3_col10" class="data row3 col10" >0.387000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row4" class="row_heading level0 row4" >2018</th>
#       <td id="T_012bc_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_012bc_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_012bc_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_012bc_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_012bc_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_012bc_row4_col5" class="data row4 col5" >0.185000</td>
#       <td id="T_012bc_row4_col6" class="data row4 col6" >0.820000</td>
#       <td id="T_012bc_row4_col7" class="data row4 col7" >0.316000</td>
#       <td id="T_012bc_row4_col8" class="data row4 col8" >0.767000</td>
#       <td id="T_012bc_row4_col9" class="data row4 col9" >0.742000</td>
#       <td id="T_012bc_row4_col10" class="data row4 col10" >0.423000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_012bc_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_012bc_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_012bc_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_012bc_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_012bc_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_012bc_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_012bc_row5_col6" class="data row5 col6" >0.339000</td>
#       <td id="T_012bc_row5_col7" class="data row5 col7" >0.832000</td>
#       <td id="T_012bc_row5_col8" class="data row5 col8" >0.364000</td>
#       <td id="T_012bc_row5_col9" class="data row5 col9" >0.353000</td>
#       <td id="T_012bc_row5_col10" class="data row5 col10" >0.763000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_012bc_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_012bc_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_012bc_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_012bc_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_012bc_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_012bc_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_012bc_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_012bc_row6_col7" class="data row6 col7" >0.485000</td>
#       <td id="T_012bc_row6_col8" class="data row6 col8" >0.962000</td>
#       <td id="T_012bc_row6_col9" class="data row6 col9" >0.933000</td>
#       <td id="T_012bc_row6_col10" class="data row6 col10" >0.586000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row7" class="row_heading level0 row7" >2021</th>
#       <td id="T_012bc_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_012bc_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_012bc_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_012bc_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_012bc_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_012bc_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_012bc_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_012bc_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_012bc_row7_col8" class="data row7 col8" >0.502000</td>
#       <td id="T_012bc_row7_col9" class="data row7 col9" >0.486000</td>
#       <td id="T_012bc_row7_col10" class="data row7 col10" >0.937000</td>
#     </tr>
#     <tr>
#       <th id="T_012bc_level0_row8" class="row_heading level0 row8" >2022</th>
#       <td id="T_012bc_row8_col0" class="data
